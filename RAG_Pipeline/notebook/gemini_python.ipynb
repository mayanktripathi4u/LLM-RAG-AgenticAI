# %%
# !pip install google-genai

# %%
from google import genai
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Check and load GEMINI_API_KEY from .env file
api_key = os.getenv("GEMINI_API_KEY")
if not api_key:
    raise ValueError("GEMINI_API_KEY environment variable is missing or empty. Please set it before running this notebook.")

# %%
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="why is the sky blue?"
)

print(response.text)
# Out:
# The sky is blue because of a phenomenon called **Rayleigh scattering**. Here's a breakdown:
#
# *   **Sunlight is made of all colors:** White sunlight is actually a mix of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, and violet).
#
# *   **Light travels in waves:** Light travels in waves, and different colors have different wavelengths. Blue and violet light have shorter wavelengths, while red and orange have longer wavelengths.
#
# *   **Scattering by air molecules:** When sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen). These collisions cause the light to scatter in different directions.
#
# *   **Rayleigh scattering is wavelength-dependent:** Rayleigh scattering is much more effective at scattering shorter wavelengths (blue and violet light) than longer wavelengths (red and orange light). The amount of scattering is inversely proportional to the fourth power of the wavelength.  This means blue light is scattered about 10 times more than red light.
#
# *   **Why not violet?** Violet light is scattered even more than blue light, but there are a couple of reasons why we see a blue sky instead of a violet one:
#
#     *   **Sunlight emits less violet light:** The sun emits slightly less violet light than blue light.
#     *   **Our eyes are more sensitive to blue:** Human eyes are also more sensitive to blue light than violet light.
#
# *   **The result: Blue light dominates:** Because blue light is scattered more effectively and our eyes are more sensitive to it, we see the sky as blue.
#
# **In simpler terms:**
#
# Imagine throwing a small ball (blue light) and a big ball (red light) at a bunch of obstacles (air molecules). The small ball is more likely to bounce off in random directions, while the big ball is more likely to go straight through. That's similar to how blue light is scattered more than red light in the atmosphere.

# %%
response = client.models.generate_content_stream(
    model="gemini-2.0-flash",
    contents="why is the sky blue?"
)

for stream in response:
    print(stream.text, end="", flush=True)
# Out:
# The sky is blue due to a phenomenon called **Rayleigh scattering**. Here's the breakdown:
#
# *   **Sunlight is made of all colors:** White light from the sun is actually a mixture of all the colors of the rainbow.
#
# *   **Entering the Atmosphere:** When sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen).
#
# *   **Scattering of Light:** This collision causes the light to scatter in different directions. The amount of scattering depends on the wavelength (color) of the light.
#
# *   **Shorter Wavelengths Scatter More:** Shorter wavelengths of light (blue and violet) are scattered much more strongly than longer wavelengths (red and orange). This is Rayleigh scattering in action.
#
# *   **Why Blue, Not Violet?** Violet light is scattered even more than blue, but the sun emits slightly less violet light than blue light. Also, our eyes are more sensitive to blue. As a result, we perceive the sky as blue.
#
# **In simple terms:** Imagine throwing a handful of small balls (blue and violet light) and a handful of larger balls (red and orange light) at a bunch of obstacles. The small balls are more likely to bounce off in different directions, while the larger balls are more likely to keep going straight through.
#
# **Sunrise/Sunset:** At sunrise and sunset, the sunlight has to travel through a much greater distance of atmosphere to reach our eyes. This means that almost all of the blue light is scattered away before it gets to us. The longer wavelengths (red and orange) are less scattered and can pass through, giving us the beautiful red and orange hues of the sky at those times.
